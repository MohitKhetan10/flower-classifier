# %% [markdown]
# <a href="https://colab.research.google.com/github/MohitKhetan10/flower-classifier/blob/main/COMPARISON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Upload both trained models (e.g., flowers_vgg19.keras and flowers_resnet152.keras)
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b0c678d-4eda-4c3e-b0fc-f3ffe4044a9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b0c678d-4eda-4c3e-b0fc-f3ffe4044a9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Step 2: Load models
from tensorflow.keras.models import load_model
vgg_model = load_model("flowers_vgg19.keras")
resnet_model = load_model("flowers_resnet152.keras")

# Step 3: Reload Flowers dataset
import tensorflow as tf
import tensorflow_datasets as tfds

(ds_train, ds_val), ds_info = tfds.load(
    "tf_flowers",
    split=["train[:80%]", "train[80%:]"],
    as_supervised=True,
    with_info=True
)

# Preprocessing functions
def preprocess_vgg(image, label):
    image = tf.image.resize(image, (224,224))
    image = tf.keras.applications.vgg19.preprocess_input(image)
    return image, label

def preprocess_resnet(image, label):
    image = tf.image.resize(image, (224,224))
    image = tf.keras.applications.resnet.preprocess_input(image)
    return image, label

batch_size = 32
val_ds_vgg = ds_val.map(preprocess_vgg).batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_ds_resnet = ds_val.map(preprocess_resnet).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Step 4: Evaluate both models
vgg_loss, vgg_acc = vgg_model.evaluate(val_ds_vgg)
print(f"VGG19 Validation Accuracy: {vgg_acc:.4f}")

resnet_loss, resnet_acc = resnet_model.evaluate(val_ds_resnet)
print(f"ResNet152 Validation Accuracy: {resnet_acc:.4f}")

# Step 5: Confusion matrices
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

class_names = ["daisy", "dandelion", "roses", "sunflowers", "tulips"]

def plot_confusion_matrix(model, preprocess_fn, title):
    y_true, y_pred = [], []
    for images, labels in ds_val.map(preprocess_fn).batch(batch_size):
        preds = model.predict(images)
        y_true.extend(labels.numpy())
        y_pred.extend(np.argmax(preds, axis=1))
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names)
    plt.title(title)
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.show()

# Plot confusion matrices
plot_confusion_matrix(vgg_model, preprocess_vgg, "Confusion Matrix - VGG19")
plot_confusion_matrix(resnet_model, preprocess_resnet, "Confusion Matrix - ResNet152")

# Step 6: Side-by-side comparison
print("Comparison:")
print(f"VGG19 Accuracy    : {vgg_acc:.4f}")
print(f"ResNet152 Accuracy: {resnet_acc:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 4 variables whereas the saved optimizer has 6 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# WARNING:absl:Variant folder /root/tensorflow_datasets/tf_flowers/3.0.1 has no dataset_info.json
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/tf_flowers/incomplete.JGGA97_3.0.1/tf_flowers-train.tfrecord*...:   0%|   …
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.1. Subsequent calls will reuse this data.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 499s 21s/step - accuracy: 0.8460 - loss: 0.5019
# VGG19 Validation Accuracy: 0.8460
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from PIL import Image
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload a flower image (JPG)
uploaded = files.upload()   # Pick a .jpg file from your computer
img_path = list(uploaded.keys())[0]

# Step 2: Load and preprocess image for ResNet152
img = Image.open(img_path).convert("RGB")
img = img.resize((224,224))

img_array_resnet = image.img_to_array(img)
img_array_resnet = np.expand_dims(img_array_resnet, axis=0)
img_array_resnet = tf.keras.applications.resnet.preprocess_input(img_array_resnet)

# Step 3: Predict with ResNet152
resnet_predictions = resnet_model.predict(img_array_resnet)
resnet_class = np.argmax(resnet_predictions[0])

# Step 4: Preprocess for VGG19
img_array_vgg = image.img_to_array(img)
img_array_vgg = np.expand_dims(img_array_vgg, axis=0)
img_array_vgg = tf.keras.applications.vgg19.preprocess_input(img_array_vgg)

vgg_predictions = vgg_model.predict(img_array_vgg)
vgg_class = np.argmax(vgg_predictions[0])

# Step 5: Show results
class_names = ["daisy", "dandelion", "roses", "sunflowers", "tulips"]

plt.imshow(img)
plt.axis("off")
plt.title(f"ResNet152: {class_names[resnet_class]} | VGG19: {class_names[vgg_class]}")
plt.show()
# Out:
#      <input type="file" id="files-a1397986-dd72-4370-bded-61be0c7daa11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1397986-dd72-4370-bded-61be0c7daa11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
